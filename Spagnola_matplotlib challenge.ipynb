# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
demo = pd.read_csv('cces_example_data.csv')
demo.head()
# Out:
#    pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  pid3  \
# 0             2            6    2     2         1   56           6     1
# 1             2            4    2     5         1   53          13     1
# 2             1            2    1     2         1   69          10     2
# 3             2            3    1     6         1   76          97     1
# 4             4            5    2     6         1   83           4     1
#
#    ideo5  QueerPhobia  ...  InterGBiasParty  InterGBiasCand  InterGBiasSup  \
# 0      1     1.000000  ...              -99             -99            -96
# 1      2     3.000000  ...             -100            -100           -100
# 2      5     4.333333  ...               99              99             96
# 3      3     1.000000  ...              -86             -91            -89
# 4      2     1.000000  ...              -80             -88            -87
#
# ...

# %% [markdown]
# One figure that I am learning how to create and demonstrate is a stem plot. I think this is very similar to a bar graph; however, due to the sheer amount of data in this csv file, a stem plot would (hopefully) allow me to display the data without the graph looking visually claustrophobic.

# %%
import numpy as np

# %%
fig1, ax1 = plt.subplots()
x = np.linspace(0.1, 2 * np.pi, 41)
y = np.exp(np.sin(x))
plt.stem(x, y)
plt.show()

# %% [markdown]
# Example from the matplotlib documentation to ensure that everything was running smoothly

# %%
type(demo['sex'])
# Out:
# pandas.core.series.Series

# %%
fig1, ax1 = plt.subplots()
x = demo['age']
y = demo['educ']
plt.stem(x, y)
plt.show()

# %% [markdown]
# This actually turned out fairly cluttered but I'm happy it worked!

# %%
df_demo = pd.DataFrame(demo)
df_demo.head()
# Out:
#    pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  pid3  \
# 0             2            6    2     2         1   56           6     1
# 1             2            4    2     5         1   53          13     1
# 2             1            2    1     2         1   69          10     2
# 3             2            3    1     6         1   76          97     1
# 4             4            5    2     6         1   83           4     1
#
#    ideo5  QueerPhobia  ...  InterGBiasParty  InterGBiasCand  InterGBiasSup  \
# 0      1     1.000000  ...              -99             -99            -96
# 1      2     3.000000  ...             -100            -100           -100
# 2      5     4.333333  ...               99              99             96
# 3      3     1.000000  ...              -86             -91            -89
# 4      2     1.000000  ...              -80             -88            -87
#
# ...

# %%
fig2, (ax1, ax2) = plt.subplots(1,2)
ax1.plot(x[0], y[0])
ax1.set_title('Age Histogram')
ax2.plot(x[0], y[0])
ax2.set_title('Political Identity')

plt.show()

# %%
fig3, ax1 = plt.subplots()
x = demo['Evaluation']
y = demo['age']
ax1.set_title('Evaluations by Age')
plt.bar(x, y)
plt.show()

# %%
fig4, ax1 = plt.subplots(figsize = (10, 8))
x = demo['ConMediaUse']
y = demo['ImmiPhobia']
ax1.set_title('Media Use Juxtaposed to Xenophobia')
plt.scatter(x, y)
plt.show()
