# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
sns.set_theme(style="darkgrid")

# %%
df_diabetes = pd.read_csv("Diabetes.csv")

# %%
df_diabetes
# Out:
#      Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# 0              2  115.863387      56.410731      24.336736   94.385783
# 1              2   92.490122      70.615520      23.443591  138.652426
# 2              1   88.141469      63.262618      23.404364  149.358082
# 3              2  108.453101      67.793632      20.751580  108.751638
# 4              1  127.849443      94.725685      22.603078   25.269987
# ..           ...         ...            ...            ...         ...
# 995            1  103.496355      41.059401      24.930299   43.675978
# 996            1   60.714150      64.082842      24.689064  111.562745
# 997            0   97.597727      64.122312      22.140339  108.138552
# 998            0   66.775137      55.908797      24.885274  219.521484
# 999            0   87.647268      69.111593      25.621266  134.335745
#
#            BMI  DiabetesPedigreeFunction        Age  Diagnosis
# ...

# %%
sns.scatterplot(x=df_diabetes['BMI'], y=df_diabetes['Glucose'])
plt.show()

# %%
sns.relplot(data=df_diabetes, x='BMI' , y='Glucose', hue="Pregnancies")

# %%
sns.relplot(data=df_diabetes, x='BMI' , y='Glucose', hue="Pregnancies", size="Pregnancies")

# %%
sns.relplot(data=df_diabetes, x='BMI' , y='Glucose', hue="Pregnancies", size="Pregnancies", sizes =(10, 50))

# %%
sns.relplot(data=df_diabetes, x='BMI' , y='Glucose', hue="Pregnancies", size="Pregnancies", sizes =(10, 50))
plt.xlim(18, 37)
plt.ylim(50, 140)

plt.show()

# %%
sns.relplot(data=df_diabetes, x='Age' , y='Insulin')

# %%
sns.relplot(data=df_diabetes, x='Age' , y='Insulin', hue="Pregnancies", size="Pregnancies")

# %%
sns.relplot(data=df_diabetes, x='Age' , y='Insulin', hue="Pregnancies", size="Pregnancies")
plt.xlim(15, 82)
plt.ylim(-100, 300)

plt.show()

# %% [markdown]
# Relplot can be used to create legends or style guides for the plots that it can be used to create. These can help visually organize data to a greater extent to help with conveying information

# %%
df_salary = pd.read_csv("Salary Data.csv")
df_salary
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
sns.set(style="whitegrid")

# %%
plt.figure()
sns.scatterplot(x="Age", y="Salary", data=df_salary)
plt.title('Default Scatter Plot: Age vs Salary')
plt.show()

# %%
plt.figure()
sns.scatterplot(x="Age", y="Salary", hue="Education Level", style="Gender", data=df_salary)
plt.title('Default Scatter Plot: Age vs Salary by Education Level and Gender')
plt.show()

# %%
education_colors = {"Bachelor's": "green", "Master's": "blue", "PhD": "red"}
plt.figure()
sns.scatterplot(x="Age", y="Salary", hue="Education Level", style="Gender", data=df_salary, palette=education_colors)
plt.title('Default Scatter Plot: Age vs Salary by Education Level and Gender')
plt.show()

# %%
education_colors = {"Bachelor's": "green", "Master's": "blue", "PhD": "red"}
gender_markers = {"Female": "o", "Male": "s"}
plt.figure()
sns.scatterplot(x="Age", y="Salary", hue="Education Level", style="Gender", data=df_salary, palette=education_colors, markers=gender_markers)
plt.title('Default Scatter Plot: Age vs Salary by Education Level and Gender')
plt.show()

# %%
education_colors = {"Bachelor's": "green", "Master's": "blue", "PhD": "red"}
gender_markers = {"Female": "o", "Male": "s"}
plt.figure()
sns.set_style("ticks")
sns.scatterplot(x="Age", y="Salary", hue="Education Level", style="Gender", data=df_salary, palette=education_colors, markers=gender_markers)
plt.title('Default Scatter Plot: Age vs Salary by Education Level and Gender')
plt.show()

# %%
education_colors = {"Bachelor's": "green", "Master's": "blue", "PhD": "red"}
gender_markers = {"Female": "o", "Male": "s"}
plt.figure(figsize=(12, 8))
sns.set_style("ticks")
sns.scatterplot(x="Age", y="Salary", hue="Education Level", style="Gender", data=df_salary, palette=education_colors, markers=gender_markers)
plt.legend(ncol=2, frameon=False, loc= "lower right" )
plt.title('Default Scatter Plot: Age vs Salary by Education Level and Gender')
plt.show()

# %%
gender_colors = {"Female": "red", "Male": "blue"}
plt.figure(figsize=(10, 8))
sns.set_style("ticks")
Bachelors=sns.scatterplot(x="Age", y="Salary", hue="Gender", data=df_salary[df_salary["Education Level"] == "Bachelor's"], palette=gender_colors)
Bachelors.set_xlim(25, 50)
Bachelors.set_ylim(50000, 250000)
plt.legend(frameon=False, loc= "upper left" )
plt.title("Default Scatter Plot: Age vs Salary Based on Gender Among Bachelor's Degree Holders")
plt.show()

# %%
gender_colors = {"Female": "red", "Male": "blue"}
plt.figure(figsize=(10, 8))
sns.set_style("ticks")
Masters=sns.scatterplot(x="Age", y="Salary", hue="Gender", data=df_salary[df_salary["Education Level"] == "Master's"], palette=gender_colors)
Masters.set_xlim(25, 50)
Masters.set_ylim(50000, 250000)
plt.legend(frameon=False, loc= "upper left" )
plt.title("Default Scatter Plot: Age vs Salary Based on Gender Among Masters's Degree Holders")
plt.show()

# %%
gender_colors = {"Female": "red", "Male": "blue"}
plt.figure(figsize=(10, 8))
sns.set_style("ticks")
PhD=sns.scatterplot(x="Age", y="Salary", hue="Gender", data=df_salary[df_salary["Education Level"] == "PhD"], palette=gender_colors)
PhD.set_xlim(25, 50)
PhD.set_ylim(50000, 250000)
plt.legend(frameon=False, loc= "upper left" )
plt.title("Default Scatter Plot: Age vs Salary Based on Gender Among PhD Degree Holders")
plt.show()

# %%
sns.barplot(x='Years of Experience', y='Education Level', hue='Gender', data=df_salary)
# Out:
# <Axes: xlabel='Years of Experience', ylabel='Education Level'>

# %%
sns.barplot(x='Education Level', y='Years of Experience', hue='Gender', capsize=0.1, data=df_salary)
# Out:
# <Axes: xlabel='Education Level', ylabel='Years of Experience'>

# %%
sns.barplot(x='Education Level', y='Years of Experience', hue='Gender', capsize=0.1, data=df_salary, errorbar=None)
# Out:
# <Axes: xlabel='Education Level', ylabel='Years of Experience'>

# %%
sns.barplot(x='Education Level', y='Years of Experience', hue='Gender', capsize=0.1, data=df_salary, errorbar=None, palette='dark:blue' , hue_order=['Female', 'Male'])
# Out:
# <Axes: xlabel='Education Level', ylabel='Years of Experience'>
